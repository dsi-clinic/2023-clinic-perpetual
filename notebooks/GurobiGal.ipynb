# %% [markdown]
# # Gurobi Exploration

# %%
import gurobipy as gp
from gurobipy import GRB
import pandas as pd
import numpy as np
import sys
import math
import random
from itertools import permutations

# %%
#initializing model
m = gp.Model("weekly_tote_distribution") 

#loading data 
TruckPoints = pd.read_csv('../data/truck_service_pts_galv.csv')

# %%
TruckPoints.head()
# Out:
#             Name  Longitude   Latitude  Daily_Pickup_Totes  \
# 0  Moody Gardens -94.852300  29.273600                   0
# 1     Sugar Bean -94.870418  29.261029                   1
# 2        MAC-IES -94.791385  29.298912                   1
# 3     Good Dough -94.808531  29.290612                   1
# 4     Porch Cafe -94.750192  29.319581                   1
#
#    Weekly_Dropoff_Totes  user_ratings_total    category  rating weekly_high  \
# 0                     0                 NaN         NaN     NaN         NaN
# 1                     1               476.0        cafe     4.7         200
# 2                     1                73.0  restaurant     5.0        1500
# 3                     1                68.0      bakery     4.6          70
# 4                     1               332.0  restaurant     4.1         300
#
#   weekly_low best_weekly_estimate                               Address  \
# 0        NaN                  NaN                                   NaN
# 1         50                  200               11 Evia Main, Galveston
# 2       1050                 1500           1110 23rd Street, Galveston
# 3         35                   70           1508 39th Street, Galveston
# 4        NaN                  100  1625 East Beach Drive #2A, Galveston
#
#                          geometry Adoption Adoption Guess Visited  Influence  \
# 0                             NaN      NaN            NaN      NaN       NaN
# 1  POINT (-94.8704183 29.2610286)  Curious           High       No      High
# 2  POINT (-94.7913851 29.2989118)  Curious           High       No       Low
# 3   POINT (-94.808531 29.2906119)  Curious           High       No       Med
# 4  POINT (-94.7501916 29.3195806)  Curious           High       No       Low
#
#   location_type pickup_type  id
# 0         depot       Truck NaN
# 1        indoor       Truck NaN
# 2        indoor       Truck NaN
# 3        indoor       Truck NaN
# 4        indoor       Truck NaN

# %%
#splitting by indoor outdoor

DropoffOnly = TruckPoints.copy()
DropoffOnly = DropoffOnly[DropoffOnly['Weekly_Dropoff_Totes'] >= 1]
DropoffOnly
# Out:
#                                        Name  Longitude   Latitude  \
# 1                                Sugar Bean -94.870418  29.261029
# 2                                   MAC-IES -94.791385  29.298912
# 3                                Good Dough -94.808531  29.290612
# 4                                Porch Cafe -94.750192  29.319581
# 5                             Coastal Grill -94.789455  29.308158
# ..                                      ...        ...        ...
# 166                             Gypsy Joynt -94.831648  29.274172
# 167                             Café Canela -94.830826  29.274424
# 168  Gino's Italian Restaurant and Pizzeria -94.832217  29.275314
# 169                              Vida Agave -94.795515  29.301840
# 170                  Seawall Coffee Company -94.867823  29.244639
#
#      Daily_Pickup_Totes  Weekly_Dropoff_Totes  user_ratings_total    category  \
# 1                     1                     1               476.0        cafe
# 2                     1                     1                73.0  restaurant
# 3                     1                     1                68.0      bakery
# 4                     1                     1               332.0  restaurant
# 5                     1                     1               814.0  restaurant
# ..                  ...                   ...                 ...         ...
# 166                   2                     1               622.0  restaurant
# 167                   1                     1               412.0  restaurant
# 168                   1                     1              1056.0  restaurant
# 169                   1                     1               155.0  restaurant
# 170                   2                     1                47.0  restaurant
#
#      rating weekly_high weekly_low best_weekly_estimate  \
# 1       4.7         200         50                  200
# 2       5.0        1500       1050                 1500
# 3       4.6          70         35                   70
# 4       4.1         300        NaN                  100
# 5       4.6         500        100                  500
# ..      ...         ...        ...                  ...
# 166     4.5        2000       1400                 2000
# 167     4.6         350         50                  350
# 168     4.3          35          5                   35
# 169     4.7          70         10                   70
# 170     4.5        1050        350                 1050
#
#                                   Address  \
# 1                 11 Evia Main, Galveston
# 2             1110 23rd Street, Galveston
# 3             1508 39th Street, Galveston
# 4    1625 East Beach Drive #2A, Galveston
# 5              1827 The Strand, Galveston
# ..                                    ...
# 166   6105 Stewart Rd Galveston, TX 77551
# 167  6105 Stewart Road Suite C, Galveston
# 168          6124 Stewart Road, Galveston
# 169            711 25th Street, Galveston
# 170                                   NaN
#
#                                        geometry   Adoption Adoption Guess  \
# 1                POINT (-94.8704183 29.2610286)    Curious           High
# 2                POINT (-94.7913851 29.2989118)    Curious           High
# 3                 POINT (-94.808531 29.2906119)    Curious           High
# 4                POINT (-94.7501916 29.3195806)    Curious           High
# 5                  POINT (-94.789455 29.308158)  Skeptical           High
# ..                                          ...        ...            ...
# 166  POINT (-94.8316475822502 29.2741723877485)        TBD            Med
# 167              POINT (-94.8308258 29.2744235)  Skeptical            Med
# 168               POINT (-94.832217 29.2753139)  Skeptical            Med
# 169                 POINT (-94.795515 29.30184)  Skeptical            Med
# 170   POINT (-94.8678233612548 29.244638725096)    Curious            Med
#
#     Visited  Influence location_type pickup_type  id
# 1         No      High        indoor       Truck NaN
# 2         No       Low        indoor       Truck NaN
# 3         No       Med        indoor       Truck NaN
# 4         No       Low        indoor       Truck NaN
# 5         No       Med        indoor       Truck NaN
# ..       ...       ...           ...         ...  ..
# 166      Yes       Med        indoor       Truck NaN
# 167      Yes       Low        indoor       Truck NaN
# 168      Yes       Low        indoor       Truck NaN
# 169      Yes       Low        indoor       Truck NaN
# 170      Yes       Low        indoor       Truck NaN
#
# [170 rows x 20 columns]

# %%
#Drop off Only Route, changing Lat and Long columns to Coordinate for Gurobi 

def create_coordinates(row):
    return f'({row["Latitude"]}, {row["Longitude"]})'

# Apply the function to create a new 'coordinates' column
DropoffOnly['Coordinates'] = DropoffOnly.apply(create_coordinates, axis=1)

# Display the DataFrame with the new 'coordinates' column
len(DropoffOnly)
# Out:
# 170

# %%
#Starting Model

#number of locations
n=170
locations = [*range(n)]

#number of vans 
K=2
vans = [*range(K)]

#number of points is coordinates
points = DropoffOnly['Coordinates'].tolist()

# Extract coordinates from strings and convert to floats
points = [[float(coord) for coord in point.strip('()').split(',')] for point in points]

# Dict of Euclidean Distance
time = {(i, j): math.sqrt(sum((points[i][k] - points[j][k]) ** 2 for k in range(2)))
        for i in locations for j in locations if i != j}

# %%
#adding variables from gurobi, these can be changed:
# x =1, if van  k  visits and goes directly from location  i to location j 
x = m.addVars(time.keys(), vans, vtype=GRB.BINARY, name='FromToBy')

# y = 1, if customer i is visited by van k
y = m.addVars(locations, vans, vtype=GRB.BINARY, name='visitBy')

# Number of vans used is a decision variable
z = m.addVars(vans, vtype=GRB.BINARY, name='used')

# Travel time per van
t = m.addVars(vans, ub=120, name='travelTime')

#travel time
s = m.addVar(name='maxTravelTime')

# %%
#adding contraits from gurobi, removing time constraint for now

# Travel time constraint
# Exclude the time to return to the depot

travelTime = m.addConstrs((gp.quicksum(time[i,j]*x[i,j,k] for i,j in time.keys() if j > 0) == t[k] for k in vans), 
                          name='travelTimeConstr' )

# Van utilization constraint
visitCustomer = m.addConstrs((y[i,k] <= z[k]  for k in vans for i in locations if i > 0), name='visitCustomer' )

# Visit all customers
visitAll = m.addConstrs((y.sum(i,'*') == 1 for i in locations if i > 0), name='visitAll' )

# Depot constraint
depotConstr = m.addConstrs((y[0, k] == z[k] for k in vans), name='depotConstr' )

# Arriving at a customer location constraint
ArriveConstr = m.addConstrs((x.sum('*',j,k) == y[j,k] for j,k in y.keys()), name='ArriveConstr' )

# Leaving a customer location constraint
LeaveConstr = m.addConstrs((x.sum(j,'*',k) == y[j,k] for j,k in y.keys()), name='LeaveConstr' )

breakSymm = m.addConstrs((y.sum('*',k-1) >= y.sum('*',k) for k in vans if k>0), name='breakSymm' )

# %%
m.ModelSense = GRB.MINIMIZE
m.setObjectiveN(z.sum(), 0, priority=1, name="Number of vans")
m.setObjectiveN(s, 1, priority=0, name="Travel time")

# %%
# Callback - use lazy constraints to eliminate sub-tours
def subtourelim(model, where):
    if where == GRB.Callback.MIPSOL:
        # make a list of edges selected in the solution
        vals = model.cbGetSolution(model._x)
        selected = gp.tuplelist((i,j) for i, j, k in model._x.keys()
                                if vals[i, j, k] > 0.5)
        # find the shortest cycle in the selected edge list
        tour = subtour(selected)
        if len(tour) < n: 
            for k in vans:
                model.cbLazy(gp.quicksum(model._x[i, j, k]
                                         for i, j in permutations(tour, 2))
                             <= len(tour)-1)


# Given a tuplelist of edges, find the shortest subtour not containing depot (0)
def subtour(edges):
    unvisited = list(range(1, n))
    cycle = range(n+1)  # initial length has 1 more city
    while unvisited:
        thiscycle = []
        neighbors = unvisited
        while neighbors:
            current = neighbors[0]
            thiscycle.append(current)
            if current != 0:
                unvisited.remove(current)
            neighbors = [j for i, j in edges.select(current, '*')
                         if j == 0 or j in unvisited]
        if 0 not in thiscycle and len(cycle) > len(thiscycle):
            cycle = thiscycle
    return cycle

# %%
m.write('weekly_tote_distribution.lp')

# Run optimization engine
m._x = x
m.Params.LazyConstraints = 1
m.optimize(subtourelim)
# Out:
# Warning: variables 0 and 57804 have the same name "FromToBy[0,1,0]"
# Warning: linear constraint 0 and linear constraint 1192 have the same name "visitCustomer[0,1]"
# Warning: to let Gurobi read it back, use rlp format
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
#
# User-callback calls 6, time in user-callback 0.00 sec
# ---------------------------------------------------------------------------
# GurobiError                               Traceback (most recent call last)
# /Users/jescib/Downloads/ds_clinic1/2023-clinic-perpetual/notebooks/GurobiGal.ipynb Cell 12 line 6
#       <a href='vscode-notebook-cell:/Users/jescib/Downloads/ds_clinic1/2023-clinic-perpetual/notebooks/GurobiGal.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> m._x = x
#       <a href='vscode-notebook-cell:/Users/jescib/Downloads/ds_clinic1/2023-clinic-perpetual/notebooks/GurobiGal.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a> m.Params.LazyConstraints = 1
# ----> <a href='vscode-notebook-cell:/Users/jescib/Downloads/ds_clinic1/2023-clinic-perpetual/notebooks/GurobiGal.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a> m.optimize(subtourelim)
#
# File src/gurobipy/model.pxi:875, in gurobipy.Model.optimize()
#
# GurobiError: Model too large for size-limited license; visit https://www.gurobi.com/free-trial for a full license

# %%
# Print optimal routes
for k in vans:
    route = gp.tuplelist((i,j) for i,j in time.keys() if x[i,j,k].X > 0.5)
    if route:
        i = 0
        print(f"Route for van {k}: {i}", end='')
        while True:
            i = route.select(i, '*')[0][1]
            print(f" -> {i}", end='')
            if i == 0:
                break
        print(f". Travel time: {round(t[k].X,2)} min")

print(f"Max travel time: {round(s.X,2)}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/jescib/Downloads/ds_clinic1/2023-clinic-perpetual/notebooks/GurobiGal.ipynb Cell 13 line 3
#       <a href='vscode-notebook-cell:/Users/jescib/Downloads/ds_clinic1/2023-clinic-perpetual/notebooks/GurobiGal.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> # Print optimal routes
#       <a href='vscode-notebook-cell:/Users/jescib/Downloads/ds_clinic1/2023-clinic-perpetual/notebooks/GurobiGal.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> for k in vans:
# ----> <a href='vscode-notebook-cell:/Users/jescib/Downloads/ds_clinic1/2023-clinic-perpetual/notebooks/GurobiGal.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a>     route = gp.tuplelist((i,j) for i,j in time.keys() if x[i,j,k].X > 0.5)
#       <a href='vscode-notebook-cell:/Users/jescib/Downloads/ds_clinic1/2023-clinic-perpetual/notebooks/GurobiGal.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a>     if route:
#       <a href='vscode-notebook-cell:/Users/jescib/Downloads/ds_clinic1/2023-clinic-perpetual/notebooks/GurobiGal.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a>         i = 0
#
# File src/gurobipy/tuplelist.pxi:52, in gurobipy.tuplelist.__init__()
#
# File src/gurobipy/tuplelist.pxi:255, in gurobipy.tuplelist.extend()
#
# /Users/jescib/Downloads/ds_clinic1/2023-clinic-perpetual/notebooks/GurobiGal.ipynb Cell 13 line 3
#       <a href='vscode-notebook-cell:/Users/jescib/Downloads/ds_clinic1/2023-clinic-perpetual/notebooks/GurobiGal.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> # Print optimal routes
#       <a href='vscode-notebook-cell:/Users/jescib/Downloads/ds_clinic1/2023-clinic-perpetual/notebooks/GurobiGal.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> for k in vans:
# ----> <a href='vscode-notebook-cell:/Users/jescib/Downloads/ds_clinic1/2023-clinic-perpetual/notebooks/GurobiGal.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a>     route = gp.tuplelist((i,j) for i,j in time.keys() if x[i,j,k].X > 0.5)
#       <a href='vscode-notebook-cell:/Users/jescib/Downloads/ds_clinic1/2023-clinic-perpetual/notebooks/GurobiGal.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a>     if route:
#       <a href='vscode-notebook-cell:/Users/jescib/Downloads/ds_clinic1/2023-clinic-perpetual/notebooks/GurobiGal.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a>         i = 0
#
# File src/gurobipy/var.pxi:125, in gurobipy.Var.__getattr__()
#
# File src/gurobipy/var.pxi:153, in gurobipy.Var.getAttr()
#
# File src/gurobipy/attrutil.pxi:100, in gurobipy.__getattr()
#
# AttributeError: Unable to retrieve attribute 'X'
