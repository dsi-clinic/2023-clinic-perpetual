# %% [markdown]
# # FUE's of Galveston Visualization

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import folium

# %% [markdown]
# ### Visualization

# %%
# Every entry is a different restaurant
FEU_df = pd.read_csv("../data/FUE_Galveston.csv")
FEU_df.head()
# Out:
#             Name  Weekly_Dropoff_Totes  Daily_Pickup_Totes  \
# 0  Moody Gardens                   0.0                 0.0
# 1     Sugar Bean                   1.0                 1.0
# 2        MAC-IES                   1.0                 1.0
# 3     Good Dough                   1.0                 1.0
# 4     Porch Cafe                   1.0                 1.0
#
#                                 Address  Latitude  Longitude
# 0                1 Hope Blvd, Galveston   29.2736   -94.8523
# 1               11 Evia Main, Galveston   29.2610   -94.8704
# 2           1110 23rd Street, Galveston   29.2989   -94.7914
# 3           1508 39th Street, Galveston   29.2906   -94.8085
# 4  1625 East Beach Drive #2A, Galveston   29.3196   -94.7502

# %%
# We want to plot the visualization so all we need are locations of each point
FEU_coordinates = FEU_df[['Latitude', 'Longitude']]
FEU_coordinates

# turning values into list pairs
CoordinateList = FEU_coordinates.values.tolist()
# googled galveston city center
GalvestonCenter= [29.3013, -94.7977]

# built map with galveston at the centerlink used: 
# https://towardsdatascience.com/creating-a-simple-map-with-folium-and-python-4c083abfff94
map = folium.Map(location=GalvestonCenter, zoom_start=12)
for point in range(0, len(CoordinateList)):
    folium.Marker(CoordinateList[point], 
                popup=FEU_df['Name'][point]).add_to(map)
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb56ec0bc95e3add6f9caba3ac501c81 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb56ec0bc95e3add6f9caba3ac501c81&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb56ec0bc95e3add6f9caba3ac501c81 = L.map(
#                 &quot;map_cb56ec0bc95e3add6f9caba3ac501c81&quot;,
#                 {
#                     center: [29.3013, -94.7977],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6426357442a1a1602b3cd98838467910 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cb56ec0bc95e3add6f9caba3ac501c81);
#
#
#             var marker_580459a283398dfc4715f1e53f9ea958 = L.marker(
#                 [29.2736, -94.8523],
#                 {}
#             ).addTo(map_cb56ec0bc95e3add6f9caba3ac501c81);
#
#
#         var popup_6d3eaaeda9a3021b89036a27205ba9f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d561286ff8e2cc0204c96230543b46b = $(`&lt;div id=&quot;html_4d561286ff8e2cc0204c96230543b46b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Moody Gardens&lt;/div&gt;`)[0];
#                 popup_6d3eaaeda9a3021b89036a27205ba9f6.setContent(html_4d561286ff8e2cc0204c96230543b46b);
#
#
#
#         marker_580459a283398dfc4715f1e53f9ea958.bindPopup(popup_6d3eaaeda9a3021b89036a27205ba9f6)
#         ;
#
#
#
#
#             var marker_3502593e83f61b95d60063bb4a2ba960 = L.marker(
#                 [29.261, -94.8704],
#                 {}
#             ).addTo(map_cb56ec0bc95e3add6f9caba3ac501c81);
#
#
#         var popup_2f172b2a3bf7495eec652dfe88a39e6b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3f26951a56d8233fd23b065461c676eb = $(`&lt;div id=&quot;html_3f26951a56d8233fd23b065461c676eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sugar Bean&lt;/div&gt;`)[0];
#                 popup_2f172b2a3bf7495eec652dfe88a39e6b.setContent(html_3f26951a56d8233fd23b065461c676eb);
#
#
#
#         marker_3502593e83f61b95d60063bb4a2ba960.bindPopup(popup_2f172b2a3bf7495eec652dfe88a39e6b)
#         ;
#
#
#
#
#             var marker_67b9efb4e803f5ea679ad00c11b35229 = L.marker(
#                 [29.2989, -94.7914],
#                 {}
#             ).addTo(map_cb56ec0bc95e3add6f9caba3ac501c81);
#
#
#         var popup_d5e5b6e5e40c799f240c5b4ed0c98c0f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d1bfe625a4fb3cc20365e7b03dba6552 = $(`&lt;div id=&quot;html_d1bfe625a4fb3cc20365e7b03dba6552&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MAC-IES&lt;/div&gt;`)[0];
#                 popup_d5e5b6e5e40c799f240c5b4ed0c98c0f.setContent(html_d1bfe625a4fb3cc20365e7b03dba6552);
#
#
#
#         marker_67b9efb4e803f5ea679ad00c11b35229.bindPopup(popup_d5e5b6e5e40c799f240c5b4ed0c98c0f)
#         ;
#
#
#
#
#             var marker_ab589141d6c8c2af4b4e83a19ad3728a = L.marker(
#                 [29.2906, -94.8085],
#                 {}
#             ).addTo(map_cb56ec0bc95e3add6f9caba3ac501c81);
#
#
#         var popup_bbd190a324071cc95648f78195c707b9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_de9cb29f097d259faf0ddcca82884ddb = $(`&lt;div id=&quot;html_de9cb29f097d259faf0ddcca82884ddb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Good Dough&lt;/div&gt;`)[0];
#                 popup_bbd190a324071cc95648f78195c707b9.setContent(html_de9cb29f097d259faf0ddcca82884ddb);
#
#
#
#         marker_ab589141d6c8c2af4b4e83a19ad3728a.bindPopup(popup_bbd190a324071cc95648f78195c707b9)
#         ;
#
#
#
#
#             var marker_08c147fc2f7d932f03a2f86b65c2da35 = L.marker(
#                 [29.3196, -94.7502],
#                 {}
#             ).addTo(map_cb56ec0bc95e3add6f9caba3ac501c81);
#
#
#         var popup_75c3c81095e20fe7e005c854e48ab4f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2cd21f1298a70458a836bf75a3b08b4a = $(`&lt;div id=&quot;html_2cd21f1298a70458a836bf75a3b08b4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Porch Cafe&lt;/div&gt;`)[0];
#                 popup_75c3c81095e20fe7e005c854e48ab4f6.setContent(html_2cd21f1298a70458a836bf75a3b08b4a);
#
#
#
#         marker_08c147fc2f7d932f03a2f86b65c2da35.bindPopup(popup_75c3c81095e20fe7e005c854e48ab4f6)
#         ;
#
#
#
#
#             var marker_13a30e2ff6b4727ff0f52bd58f1efafd = L.marker(
#                 [29.3082, -94.7895],
#                 {}
#             ).addTo(map_cb56ec0bc9
